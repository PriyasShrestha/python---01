# %% [markdown]
# Text File
# csb file
# dictionary data to csv file
# json (Javascript object notation) File
# Binary File(image, word excel, db file..)->copy paste

# %% [markdown]
# '''
# operations
# .....................
# r read operatiom
# w write operation
# a append operation
# rb read binary operations
# wb write binary operations
# '''

# %% [markdown]
# TExt file

# %%
#we need to close file
file=open('priyas.txt','w')
file.write('This is a text file')
file.close()

# %%
#the program can be deletes as it mannually close the text file
with open('new.txt','w') as file:
    file.write('this is also a text file')

# %%
with open('priyas.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# This is a text fileHello every one my name is Priyash shrestha
# Hello every one my name is Priyash shrestha
# Hello every one my name is Priyash shresthacontent

# %%
content=input('enter your content')
with open ('priyas.txt','a') as file:
    
    file.write(content)
