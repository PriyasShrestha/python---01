# %%
set_A={1,4,3,4,5}
type(set_A)
print(set_A)
# Out:
# {1, 3, 4, 5}

# %%
a=[1,2,3,4,4,3,2,3,3,3]
set_data=set(a)
print (set_data)
# Out:
# {1, 2, 3, 4}

# %%
set_data.add(6)
set_data
# Out:
# {1, 2, 3, 4, 6}

# %%
set_data.update([7,8,5,0])
set_data
# Out:
# {0, 1, 2, 3, 4, 4.5, 5, 6, 7, 8}

# %%
set_data.remove(0)
set_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 set_data.remove(0)
#       2 set_data
#
# KeyError: 0
